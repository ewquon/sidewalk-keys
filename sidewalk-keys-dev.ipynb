# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sidewalk import SidewalkKeys

# %%
refpath = 'refdata'
prefix = 'Piano.mf'
notes = ['C4','D4','E4','F4','G4','A4','B4','C5']
keys = [40,42,44,45,47,49,51,52]
notelength = 2.0 # s
samplefreq = 44100 # Hz

# %%
sw = SidewalkKeys(refpath,prefix,notes=notes,notelength=notelength,samplefreq=samplefreq)
# Out:
# _aifc_params(nchannels=2, sampwidth=2, framerate=44100, nframes=1363238, comptype=b'NONE', compname=b'not compressed')
# sample length: 30.912426303854875 s
# _aifc_params(nchannels=2, sampwidth=2, framerate=44100, nframes=1299317, comptype=b'NONE', compname=b'not compressed')
# sample length: 29.46297052154195 s
# /Users/equon/Dropbox/Python/sidewalk_keys/piano.py:47: ComplexWarning: Casting complex values to real discards the imaginary part
#   u = np.fft.ifft(Fmean).astype(np.int16)
# _aifc_params(nchannels=2, sampwidth=2, framerate=44100, nframes=1285432, comptype=b'NONE', compname=b'not compressed')
# sample length: 29.1481179138322 s
# _aifc_params(nchannels=2, sampwidth=2, framerate=44100, nframes=1227855, comptype=b'NONE', compname=b'not compressed')
# sample length: 27.842517006802723 s
# _aifc_params(nchannels=2, sampwidth=2, framerate=44100, nframes=1384233, comptype=b'NONE', compname=b'not compressed')
# sample length: 31.388503401360545 s
# ...

# %%
sw.setup()
# Out:
# (45, 544, 1184, 129)

# %%
sw.start()

# %%
sw.stop()
